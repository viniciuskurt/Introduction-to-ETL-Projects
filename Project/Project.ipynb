# %% [markdown]
# # Etapa 1 - Extração do Dados

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("ocorrencia_2010_2020_v2.csv")
dataframe
# Out:
#      codigo_ocorrencia;codigo_ocorrencia2;ocorrencia_classificacao;ocorrencia_cidade;ocorrencia_uf;ocorrencia_aerodromo;ocorrencia_dia;ocorrencia_hora;total_recomendacoes
# 0     40211;40211;INCIDENTE;RIO DE JANEIRO;RJ;****;0...
# 1     40349;40349;INCIDENTE;BELÉM;PA;SBBE;03/01/2010...
# 2     40351;40351;INCIDENTE;RIO DE JANEIRO;RJ;SBRJ;0...
# 3     39527;39527;ACIDENTE;LUCAS DO RIO VERDE;MT;***...
# 4     40324;40324;INCIDENTE;PELOTAS;RS;SBPK;05/01/20...
# ...                                                 ...
# 5748  79757;79757;INCIDENTE GRAVE;LAGOA DA CONFUSÃO;...
# 5749  79802;79802;INCIDENTE;RIO DE JANEIRO;RJ;SBGL;3...
# 5750  79756;79756;INCIDENTE GRAVE;VICENTINA;MS;****;...
# 5751  79844;79844;INCIDENTE;RIO DE JANEIRO;RJ;SBJR;3...
# 5752  79844;79844;INCIDENTE;RIO DE JANEIRO;RJ;SBJR;0...
#
# [5753 rows x 1 columns]

# %%
#separando o arquivo por ";"

df = pd.read_csv("ocorrencia_2010_2020_v2.csv", sep=";")
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1                  BELÉM            PA                 SBBE     03/01/2010
# 2         RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3     LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4                PELOTAS            RS                 SBPK     05/01/2010
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     30/12/2020
# 5749      RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5750           VICENTINA            MS                 ****     31/12/2020
# 5751      RIO DE JANEIRO            RJ                 SBJR     31/12/2020
# 5752      RIO DE JANEIRO            RJ                 SBJR     01/01/2021
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %%
#verificando tipos de dados do dataset

df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %%
#manipulando coluna ocorrencia_dia
df.ocorrencia_dia.dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9ab1a72acb78> in <module>
#       1 #manipulando coluna ocorrencia_dia
# ----> 2 df.ocorrencia_dia.dt.month
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     492             return PeriodProperties(data, orig)
#     493
# --> 494         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# A coluna ocorrencia_dia foi carregada como tipo objeto como vimos acima, precisamos transformá-la no typo especial de data para realizar sua manipúlação.

# %%
#classsificando coluna 'ocorrencia_dia' como tipo datetame

df2 = pd.read_csv("ocorrencia_2010_2020_v2.csv", sep=";", parse_dates=['ocorrencia_dia'])

# %%
df2.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df2.ocorrencia_dia.dt.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        4
# 4        5
#         ..
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# 5752     1
# Name: ocorrencia_dia, Length: 5753, dtype: int64

# %% [markdown]
# -----------------------------

# %% [markdown]
# # Etapa 2 - Validação dos Dados

# %%
df2.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
# 5            SALVADOR            BA                 ****     2010-06-01
# 6               COARI            AM                 SBUY     2010-07-01
# 7            CANUTAMA            AM                 ****     2010-09-01
# 8            CASCAVEL            PR                 SBCA     2010-10-01
# 9       PARÁ DE MINAS            MG                 ****     2010-10-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %% [markdown]
# ### Validação da ordem de data e mês no dataset:

# %%
df3 = pd.read_csv("ocorrencia_2010_2020_v2.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df3.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                 ****     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                 ****     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                 ****     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %% [markdown]
# ### Validando os tipos de dados do dataframe.
#
#
# Criaremos uma ocorrência que irá validar se a coluna ocorrencia_dia é do tipo data, caso não seja o processo
# será parado com uma exceção'''
#
# - A biblioteca Pandera permite realizar a validação dos dados, retornando um erro caso os dados não estejam de acordo com o que precisamos.

# %%
import pandera as pa

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.DateTime)
        
    }
)
schema.validate(df3)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-24-909c69c0d550> in <module>
#       5     }
#       6 )
# ----> 7 schema.validate(df3)
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     591                 check_results.append(isinstance(result, pd.DataFrame))
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#     595                 for schema_error_dict in err.schema_errors:
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     583         for schema_component in schema_components:
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#     587                     lazy=lazy,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1882     ) -> Union[pd.DataFrame, pd.Series]:
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#    1886         )
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     199                     )
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#     203         return check_obj
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     172
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#     176                 head,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1819                 repr(series_dtype),
#    1820             )
# -> 1821             error_handler.collect_error(
#    1822                 "wrong_pandas_dtype",
#    1823                 errors.SchemaError(
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: expected series 'codigo_ocorrencia' to have type 'datetime64[ns]', got 'int64'

# %% [markdown]
# **Observe acima que ao criar schemas ele possibilita o retorno de mensagems caso algum dado esteja divergente ao nosso esquema proposto.**
#
# **O erro acima retorna que existe em agum dado inválido na coluna ocorrência_dia do Dataframe.**
#
# A vantagem de usar os SCHEMAS da biblioteca Pandera é exatamente bloquear os erros e tratá-los a cada passo do processo de validação dos Dados.

# %%
#Validaremos a seguir apenas uma coluna codigo_ocorrencia para o tipo Int

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int)
        
    }
)

# %%
schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %%
# Após verificar o sucesso na validação, podemos validar todas as colunas do nosso DataFrame

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)

# %%
schema.validate(df3)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-28-881be857fbbb> in <module>
# ----> 1 schema.validate(df3)
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     591                 check_results.append(isinstance(result, pd.DataFrame))
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#     595                 for schema_error_dict in err.schema_errors:
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     583         for schema_component in schema_components:
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#     587                     lazy=lazy,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1882     ) -> Union[pd.DataFrame, pd.Series]:
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#    1886         )
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     199                     )
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#     203         return check_obj
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     172
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#     176                 head,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1772                     series[nulls].head(constants.N_FAILURE_CASES).to_dict(),
#    1773                 )
# -> 1774                 error_handler.collect_error(
#    1775                     "series_contains_nulls",
#    1776                     errors.SchemaError(
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: non-nullable series 'ocorrencia_hora' contains null values: {4100: nan}

# %% [markdown]
# Observe que agora possímos outro erro na coluna **ocorrencia_hora** onde ela contém valores nulos.

# %%
#corrigindo erro coluna ocorrencia_hora

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)

# %%
#Verificado que os dados estão Validados

schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %% [markdown]
# ** OBS: É impostante salientar que a validação realizada nos passos anteriores agora permite valores nulos nas colunas "ocorrencia_dia" e "ocorrencia_hora"**

# %% [markdown]
# ### Validando Formato de horas em 24 horas

# %%
#criando uma expressão regular para tratar a coluna ocorrencia_hora

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)

# %%
schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %% [markdown]
# ### Validando Tamanho de caracteres em uma coluna
#
# Algumas colunas podem requerer limitado número de valores, por exempo, a coluna **ocorrencia_uf** onde é a abreviação de um Estado.

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)
schema.validate(df3)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-33-62741103ccf6> in <module>
#      13     }
#      14 )
# ---> 15 schema.validate(df3)
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     531                     f"column '{colname}' not in dataframe\n{check_obj.head()}"
#     532                 )
# --> 533                 error_handler.collect_error(
#     534                     "column_not_in_dataframe",
#     535                     errors.SchemaError(
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: column 'codigo' not in dataframe
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %% [markdown]
# ** Para tratar esse erro utilizamor o parâmetro Require: **

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)
schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %% [markdown]
# ### Require False
#
# Um caso bastante comum é trabalharmos com o Dataframe onde podem aparecer e sumir algumas colunas conforme a necessidade.
#
# se observamor no codigo abaixo, iremos inserir uma coluna que não existe e será apresentado um erro:

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)

# %% [markdown]
# ** Como observado existe o caso onde existe uma coluna com dados considerados sujos, três asteríscos.**
#
# Podemos tratá-lo a seguir na Etapa 3 realizando o processo de Limpeza de Dados.

# %%
schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %% [markdown]
# ===========================================================================================================

# %% [markdown]
# <center>***Alguns métodos de manipulação de DataFrame:***</center>

# %%
df3.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df3.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df3.loc[3]
# Out:
# codigo_ocorrencia                         39527
# codigo_ocorrencia2                        39527
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade            LUCAS DO RIO VERDE
# ocorrencia_uf                                MT
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-04 00:00:00
# ocorrencia_hora                        17:30:00
# total_recomendacoes                           0
# Name: 3, dtype: object

# %%
df3.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df3.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df3.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# 5752        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5753, dtype: object

# %%
#verificando se uma tabela é unica no DataFrame

df3.codigo_ocorrencia.is_unique
# Out:
# False

# %%
#Definindo coluna 'codigo_ocorrencia' como índice da tabela (não altera o DataFrame real, apenas no momento)

df3.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# ...                               ...                      ...
# 79757                           79757          INCIDENTE GRAVE
# 79802                           79802                INCIDENTE
# 79756                           79756          INCIDENTE GRAVE
# 79844                           79844                INCIDENTE
# 79844                           79844                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
# ...                               ...           ...                  ...
# 79757               LAGOA DA CONFUSÃO            TO                 ****
# 79802                  RIO DE JANEIRO            RJ                 SBGL
# 79756                       VICENTINA            MS                 ****
# 79844                  RIO DE JANEIRO            RJ                 SBJR
# 79844                  RIO DE JANEIRO            RJ                 SBJR
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00                    0
# 40349                 2010-01-03        11:05:00                    0
# 40351                 2010-01-03        03:00:00                    0
# 39527                 2010-01-04        17:30:00                    0
# 40324                 2010-01-05        19:25:00                    0
# ...                          ...             ...                  ...
# 79757                 2020-12-30        18:30:00                    0
# 79802                 2020-12-30        00:54:00                    0
# 79756                 2020-12-31        09:00:00                    0
# 79844                 2020-12-31        13:24:00                    0
# 79844                 2021-01-01        13:24:00                    0
#
# [5753 rows x 8 columns]

# %% [markdown]
# Caso quisesse alterar definitivamente o índice:
#
# **df3.set_index('codigo_ocorrencia' inplace=True)**
#
# Caso quisesse resetar após alterar:
#
# **df3.reset_index(drop=True, inplace=True)**

# %%
df3.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df3.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ                          2010-01-03
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0

# %%
df3.loc[1] = 20

# %%
df3.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ                       2010-01-03 00:00:00
# 1                20            20                   20                   20
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1              20                   20

# %%
df3.loc[:,'total_recomendacoes'] = 10

df3
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %%
#criando uma coluna de backup

df3['ocorrencia_uf_bkp'] = df.ocorrencia_uf

df3
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
#      ocorrencia_uf_bkp
# 0                   RJ
# 1                   PA
# 2                   RJ
# 3                   MT
# 4                   RS
# ...                ...
# 5748                TO
# 5749                RJ
# 5750                MS
# 5751                RJ
# 5752                RJ
#
# [5753 rows x 10 columns]

# %%
#Excluíndo coluna  de backup

df3.drop(['ocorrencia_uf_bkp'], axis=1, inplace=True)

# %% [markdown]
# ##### Alterando valores de uma coluna conforme uma classificação
#
# Para exemplo vamos alterar para GRAVE, na coluna 'ocorrencia_classificacao', todos as linhas que forem de SP na coluna 'ocorrencia_uf'.

# %%
df3.loc[df3.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

df3
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 ****
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                 ****
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 ****
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %%
df3.loc[df3.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                    GRAVE
# 16                39809               39809                    GRAVE
# 18                39828               39828                    GRAVE
# 26                39847               39847                    GRAVE
# 27                39768               39768                    GRAVE
# ...                 ...                 ...                      ...
# 5704              79739               79739                    GRAVE
# 5705              79705               79705                    GRAVE
# 5715              79718               79718                    GRAVE
# 5742              79800               79800                    GRAVE
# 5747              79804               79804                    GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 11           SÃO PAULO            SP                 SBMT
# 16           SÃO PAULO            SP                 ****
# 18              SANTOS            SP                 ****
# 26            SOROCABA            SP                 ****
# 27            CAMPINAS            SP                 ****
# ...                ...           ...                  ...
# 5704         SÃO PAULO            SP                 SBSP
# 5705          SOROCABA            SP                 SDCO
# 5715         SÃO PAULO            SP                 SBMT
# 5742         SÃO PAULO            SP                 SBMT
# 5747          CAMPINAS            SP                 SBKP
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 11    2010-01-10 00:00:00        14:50:00                   10
# 16    2010-01-15 00:00:00        15:00:00                   10
# 18    2010-01-15 00:00:00        17:45:00                   10
# 26    2010-01-20 00:00:00        13:10:00                   10
# 27    2010-01-21 00:00:00        20:45:00                   10
# ...                   ...             ...                  ...
# 5704  2020-12-03 00:00:00        14:42:00                   10
# 5705  2020-12-04 00:00:00        15:30:00                   10
# 5715  2020-12-11 00:00:00        13:50:00                   10
# 5742  2020-12-28 00:00:00        10:15:00                   10
# 5747  2020-12-29 00:00:00        19:00:00                   10
#
# [1373 rows x 9 columns]

# %% [markdown]
# ===========================================================================================================

# %% [markdown]
# # Etapa 3 - Limpeza dos Dados

# %% [markdown]
# Mesmo após a validação, ainda existem dados que não estão prontos para serem Transformados.
#
# Dados como #, ?, ! * devem ser retirados para que o nosso DataFrame pois não são úteis do ponto de vista lógico.
#
# - Após verificar a planilha cvs, identificamos que os arquivos a serem limpos são:
#
# **ocorrencia_uf:** (**)
#
#
# **ocorrencia_aerodromo:** (##! - #### - **** - *****)
#
#
# **ocorrencia_hora:** (NULL)

# %%
df3.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                       2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 ****  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %%
#Limpando todas as linhas de ocorrencia_aerodromo que contém ****
## pa.NA = manipula valores not avaliable em uma celula

df3.loc[df3.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df3.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                       2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 <NA>  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %%
#Fazendo a alterações no Dataset como um todo

df3.replace(['**','***','****','*****','###!','####','NULL'], pd.NA, inplace=True)

# %% [markdown]
# ### Limpeza em Tempo de Execução
#
#
# - Poderíamos ter armazenando os valores de exceção, dentro de uma váriavel:
#
#
# valores_ausentes = ['**','***','****','*****','###!','####','NULL']
#
# df3 = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
# df3.head(10)

# %%
df3
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                 <NA>
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %% [markdown]
# #### O Pandas oferece dois recursos específico para verificar qual a quantidade de dados NOT AVALIABLE do DataFrame.
#
# E mediante esses dados, podemos manipular (alterar) valores desses dados

# %%
df3.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#ou

df3.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2348
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# #### Podemos incluir valores em dados não informados:

# %%
#inserindo valor 0 em dados NA em tempo de visualização

df3.fillna(0)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                    20                  20                       20
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                    0
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                    0
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                    0
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %%
df3.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                       2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                 <NA>  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %%
#inserindo valor 0 em TODOS os dados NA definitivamente 

df3.fillna(0, inplace=True)

df3.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1                 20                  20                       20
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                       2010-01-03 00:00:00
# 1                  20            20                   20                   20
# 2      RIO DE JANEIRO            RJ                 SBRJ  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT                    0  2010-01-04 00:00:00
# 4             PELOTAS            RS                 SBPK  2010-01-05 00:00:00
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                   10
# 1              20                   10
# 2        03:00:00                   10
# 3        17:30:00                   10
# 4        19:25:00                   10

# %%
#zerou a soma dos valores 

df3.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %% [markdown]
# **Observe acima que não existem mais valores nulos acima!**

# %%
# alterando de valor 0 para 10 os valores alterados

df3.replace([10], pd.NA, inplace=True)

# %%
df3.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo           0
# ocorrencia_dia                 0
# ocorrencia_hora                0
# total_recomendacoes         5753
# dtype: int64

# %%
df3.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df3.isnull().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %% [markdown]
# ### Excluíndo valores duplicados
#
# observe que as duas ultimas linhas do DataFrame estão duplicadas. Iremos excluídas

# %%
df3
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                   20                 20                       20
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
# 5752             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                    0
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                    0
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                    0
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %%
df3.drop_duplicates(inplace=True)

df3
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211              40211                INCIDENTE
# 1                   20                 20                       20
# 2                40351              40351                INCIDENTE
# 3                39527              39527                 ACIDENTE
# 4                40324              40324                INCIDENTE
# ...                ...                ...                      ...
# 5748             79757              79757          INCIDENTE GRAVE
# 5749             79802              79802                INCIDENTE
# 5750             79756              79756          INCIDENTE GRAVE
# 5751             79844              79844                INCIDENTE
# 5752             79844              79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ
# 1                     20            20                   20
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                    0
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 5748   LAGOA DA CONFUSÃO            TO                    0
# 5749      RIO DE JANEIRO            RJ                 SBGL
# 5750           VICENTINA            MS                    0
# 5751      RIO DE JANEIRO            RJ                 SBJR
# 5752      RIO DE JANEIRO            RJ                 SBJR
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                   10
# 1                      20              20                   10
# 2     2010-01-03 00:00:00        03:00:00                   10
# 3     2010-01-04 00:00:00        17:30:00                   10
# 4     2010-01-05 00:00:00        19:25:00                   10
# ...                   ...             ...                  ...
# 5748  2020-12-30 00:00:00        18:30:00                   10
# 5749  2020-12-30 00:00:00        00:54:00                   10
# 5750  2020-12-31 00:00:00        09:00:00                   10
# 5751  2020-12-31 00:00:00        13:24:00                   10
# 5752  2021-01-01 00:00:00        13:24:00                   10
#
# [5753 rows x 9 columns]

# %% [markdown]
# # Etapa 4 - Transformação dos Dados
#
# Fazendo a manipulação para gerar novas informações que poderão ser utilizadas por outros algoritmos ou ferramentas.

# %%
valores_ausentes = ['**','****','*****','###!','####','NULL']

df3 = pd.read_csv("ocorrencia_2010_2020_v2.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes) 

df3.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                  NaN     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                  NaN     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                  NaN     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
schema.validate(df3)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-98-881be857fbbb> in <module>
# ----> 1 schema.validate(df3)
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     591                 check_results.append(isinstance(result, pd.DataFrame))
#     592             except errors.SchemaError as err:
# --> 593                 error_handler.collect_error("schema_component_check", err)
#     594             except errors.SchemaErrors as err:
#     595                 for schema_error_dict in err.schema_errors:
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     583         for schema_component in schema_components:
#     584             try:
# --> 585                 result = schema_component(
#     586                     df_to_validate,
#     587                     lazy=lazy,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1882     ) -> Union[pd.DataFrame, pd.Series]:
#    1883         """Alias for ``validate`` method."""
# -> 1884         return self.validate(
#    1885             check_obj, head, tail, sample, random_state, lazy, inplace
#    1886         )
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     199                     )
#     200             else:
# --> 201                 validate_column(check_obj, column_name)
#     202
#     203         return check_obj
#
# C:\Anaconda3\lib\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     172
#     173         def validate_column(check_obj, column_name):
# --> 174             super(Column, copy(self).set_name(column_name)).validate(
#     175                 check_obj,
#     176                 head,
#
# C:\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1772                     series[nulls].head(constants.N_FAILURE_CASES).to_dict(),
#    1773                 )
# -> 1774                 error_handler.collect_error(
#    1775                     "series_contains_nulls",
#    1776                     errors.SchemaError(
#
# C:\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: non-nullable series 'ocorrencia_aerodromo' contains null values: {0: nan, 3: nan, 5: nan, 7: nan, 9: nan, 10: nan, 13: nan, 15: nan, 16: nan, 17: nan}

# %%
#Corrigindo o erro:

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int),
    }
)

# %%
#Varificando validação

schema.validate(df3)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
# 5752              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5748   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                  NaN     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
# 5752      RIO DE JANEIRO            RJ                 SBJR     2021-01-01
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5748        18:30:00                    0
# 5749        00:54:00                    0
# 5750        09:00:00                    0
# 5751        13:24:00                    0
# 5752        13:24:00                    0
#
# [5753 rows x 9 columns]

# %%
df3.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
#Pesquisando informações de uma linha de nosso Dataframe

df3.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
#Pesquisando informações de um índice de nosso Dataframe

df3.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
#Pesquisando informações do ultimo índice de nosso Dataframe

df3.iloc[-1]
# Out:
# codigo_ocorrencia                         79844
# codigo_ocorrencia2                        79844
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       SBJR
# ocorrencia_dia              2021-01-01 00:00:00
# ocorrencia_hora                        13:24:00
# total_recomendacoes                           0
# Name: 5752, dtype: object

# %%
#Pesquisando informações de uma coluna do Dataframe

df3.loc[:, 'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# 5752    RJ
# Name: ocorrencia_uf, Length: 5753, dtype: object

# %%
#ou

df3['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# 5752    RJ
# Name: ocorrencia_uf, Length: 5753, dtype: object

# %%
#pesquisando valores nulos no DF

df3.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# ### Criando Filtros

# %%
#criando um filtro de valores nulos na coluna ocorrencia_uf

filtro = df3.ocorrencia_uf.isnull()
df3.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0

# %%
#criando um filtro de valores nulos na coluna ocorrencia_aerodromo

filtro = df3.ocorrencia_aerodromo.isnull()
df3.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 5               SALVADOR            BA                  NaN     2010-01-06
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 9          PARÁ DE MINAS            MG                  NaN     2010-01-10
# ...                  ...           ...                  ...            ...
# 5741        NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5744            GOIATUBA            GO                  NaN     2020-12-29
# 5745           MATO RICO            PR                  NaN     2020-12-29
# 5748   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5750           VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 3           17:30:00                    0
# 5           17:53:00                    0
# 7           12:30:00                    3
# 9           20:00:00                    0
# ...              ...                  ...
# 5741        13:00:00                    0
# 5744        12:00:00                    0
# 5745        10:30:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [2349 rows x 9 columns]

# %%
#criando um filtro de valores nulos na coluna ocorrencia_hora

filtro = df3.ocorrencia_hora.isnull()
df3.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4100              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4100           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4100             NaN                    0

# %% [markdown]
# ### Calculando valores Nulos dentro do DF
#
# Pelo count, podemos inicialmente realizar a conta do total de valores nulos dentro do DF:

# %%
df3.count()
# Out:
# codigo_ocorrencia           5753
# codigo_ocorrencia2          5753
# ocorrencia_classificacao    5753
# ocorrencia_cidade           5753
# ocorrencia_uf               5752
# ocorrencia_aerodromo        3404
# ocorrencia_dia              5753
# ocorrencia_hora             5752
# total_recomendacoes         5753
# dtype: int64

# %% [markdown]
# O valor total de ocorrencias é de 5753.
#
# Observer que  na coluna ocorrencia_uf temos o valor 5752 e na coluna ocorrencia_aerodromo 3404.
#
# **Isso acontece pq o count não conta valores nulos no Data Frame**

# %%
#Ocorrências com mais de 10 recomendações

filtro_recomendacoes = df3.total_recomendacoes >10

# %%
df.loc[filtro_recomendacoes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     17/02/2010
# 326         RIO DE JANEIRO            RJ                 SBRJ     12/08/2010
# 530              SÃO PAULO            SP                 ****     14/12/2010
# 727               ITÁPOLIS            SP                 SDIO     09/04/2011
# 872                 RECIFE            PE                 SBRF     13/07/2011
# 884   SÃO JOSÉ DOS PINHAIS            PR                 SBCT     15/07/2011
# 1062            UBERLÂNDIA            MG                 SBUL     15/11/2011
# 1972              BRASÍLIA            DF                 SBBR     13/04/2013
# 2795                SANTOS            SP                 ****     13/08/2014
# 3930               VITÓRIA            ES                 ****     21/02/2017
#
#      ocorrencia_hora  total_recomendacoes
# 63          20:07:00                   11
# 326         12:26:00                   19
# 530         20:15:00                   11
# 727         14:50:00                   11
# 872         09:54:00                   23
# 884         17:05:00                   11
# 1062        02:15:00                   20
# 1972        18:00:00                   11
# 2795        13:03:00                   13
# 3930        11:47:00                   12

# %%
#Cidades das ocorrências com mais de 10 recomendações

filtro_recomendacoes_cidades = df3.total_recomendacoes > 10
df3.loc [filtro_recomendacoes_cidades, 'ocorrencia_cidade']
# Out:
# 63                 SÃO PAULO
# 326           RIO DE JANEIRO
# 530                SÃO PAULO
# 727                 ITÁPOLIS
# 872                   RECIFE
# 884     SÃO JOSÉ DOS PINHAIS
# 1062              UBERLÂNDIA
# 1972                BRASÍLIA
# 2795                  SANTOS
# 3930                 VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
#Verificando lista de cidades e total de comendações:

filtro_recomendacoes_cidades = df3.total_recomendacoes > 10
df3.loc [filtro_recomendacoes_cidades, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
#Filtrando ocorrencias do tipo incidente grave

filtro_incidentes_graves = df3.ocorrencia_classificacao =='INCIDENTE GRAVE'
df3.loc [filtro_incidentes_graves, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#       ocorrencia_cidade  total_recomendacoes
# 7              CANUTAMA                    3
# 8              CASCAVEL                    2
# 9         PARÁ DE MINAS                    0
# 29             CURITIBA                    2
# 35               PALMAS                    0
# ...                 ...                  ...
# 5741       NOVA MARINGÁ                    0
# 5744           GOIATUBA                    0
# 5746      MANOEL URBANO                    0
# 5748  LAGOA DA CONFUSÃO                    0
# 5750          VICENTINA                    0
#
# [737 rows x 2 columns]

# %%
#COMBINANDO DOIS FILTROS - Incidentes Graves e SP

filtro1 = df3.ocorrencia_classificacao =='INCIDENTE GRAVE'
filtro2 = df3.ocorrencia_uf == 'SP'
df3.loc [filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5591              79540               79540          INCIDENTE GRAVE
# 5610              79566               79566          INCIDENTE GRAVE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 136            PIRASSUNUNGA            SP                 SDPY     2010-04-15
# 171               GUARULHOS            SP                 SBGR     2010-05-06
# 219               SÃO PAULO            SP                 SBMT     2010-06-08
# 297               SÃO PAULO            SP                 SBMT     2010-07-29
# 314   SÃO JOSÉ DO RIO PRETO            SP                 SBSR     2010-08-05
# ...                     ...           ...                  ...            ...
# 5591              SÃO PAULO            SP                  NaN     2020-09-12
# 5610          REGENTE FEIJÓ            SP                 SDYJ     2020-09-27
# 5704              SÃO PAULO            SP                 SBSP     2020-12-03
# 5705               SOROCABA            SP                 SDCO     2020-12-04
# 5715              SÃO PAULO            SP                 SBMT     2020-12-11
#
#      ocorrencia_hora  total_recomendacoes
# 136         20:15:00                    0
# 171         15:50:00                    0
# 219         19:30:00                    2
# 297         20:06:00                    0
# 314         12:01:00                    0
# ...              ...                  ...
# 5591        13:10:00                    0
# 5610        19:33:00                    0
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
#
# [137 rows x 9 columns]

# %%
#COMBINANDO DOIS FILTROS - Incidentes Graves ou SP

filtro1 = df3.ocorrencia_classificacao =='INCIDENTE GRAVE'
filtro2 = df3.ocorrencia_uf == 'SP'
df3.loc [filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 11            SÃO PAULO            SP                 SBMT     2010-01-10
# 16            SÃO PAULO            SP                  NaN     2010-01-15
# ...                 ...           ...                  ...            ...
# 5744           GOIATUBA            GO                  NaN     2020-12-29
# 5746      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5750          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 11          14:50:00                    8
# 16          15:00:00                    0
# ...              ...                  ...
# 5744        12:00:00                    0
# 5746        18:30:00                    0
# 5747        19:00:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [1973 rows x 9 columns]

# %%
#Ocorrências cuja (classificação == INCIDENTE GRAVE OU INCIDENTE) E estado == SP

filtro1 = df3.ocorrencia_classificacao == 'INCIDENTE GRAVE' | df3.ocorrencia_classificacao == 'INCIDENTE'
filtro2 = df3.ocorrencia_uf == 'SP'
df3.loc [filtro1 & filtro2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     278             try:
# --> 279                 result = libops.scalar_binop(x, y, op)
#     280             except (
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_binop()
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'bool' and 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-6d647949cc64> in <module>
#       1 #Ocorrências cuja (classificação == INCIDENTE GRAVE OU INCIDENTE) E estado == SP
#       2
# ----> 3 filtro1 = df3.ocorrencia_classificacao == 'INCIDENTE GRAVE' | df3.ocorrencia_classificacao == 'INCIDENTE'
#       4 filtro2 = df3.ocorrencia_uf == 'SP'
#       5 df3.loc [filtro1 & filtro2]
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __ror__(self, other)
#      69     @unpack_zerodim_and_defer("__ror__")
#      70     def __ror__(self, other):
# ---> 71         return self._logical_method(other, roperator.ror_)
#      72
#      73     @unpack_zerodim_and_defer("__xor__")
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    4987         rvalues = extract_array(other, extract_numpy=True)
#    4988
# -> 4989         res_values = ops.logical_op(lvalues, rvalues, op)
#    4990         return self._construct_result(res_values, name=res_name)
#    4991
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     353         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     354
# --> 355         res_values = na_logical_op(lvalues, rvalues, op)
#     356         # error: Cannot call function of unknown type
#     357         res_values = filler(res_values)  # type: ignore[operator]
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     286             ) as err:
#     287                 typ = type(y).__name__
# --> 288                 raise TypeError(
#     289                     f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     290                     f"and scalar of type [{typ}]"
#
# TypeError: Cannot perform 'ror_' with a dtyped [object] array and scalar of type [bool]

# %% [markdown]
# Note q o erro acima se dá por falta de colocar as comparações do OU dentro de parenteses:

# %%
filtro1 = (df3.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df3.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df3.ocorrencia_uf == 'SP'
df3.loc [filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           SÃO PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5704         SÃO PAULO            SP                 SBSP     2020-12-03
# 5705          SOROCABA            SP                 SDCO     2020-12-04
# 5715         SÃO PAULO            SP                 SBMT     2020-12-11
# 5742         SÃO PAULO            SP                 SBMT     2020-12-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
# 5742        10:15:00                    0
# 5747        19:00:00                    0
#
# [985 rows x 9 columns]

# %%
#fazendo a mesma coisa anterior utilizando a função is in

filtro1 = df3.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df3.ocorrencia_uf == 'SP'
df3.loc [filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           SÃO PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5704         SÃO PAULO            SP                 SBSP     2020-12-03
# 5705          SOROCABA            SP                 SDCO     2020-12-04
# 5715         SÃO PAULO            SP                 SBMT     2020-12-11
# 5742         SÃO PAULO            SP                 SBMT     2020-12-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
# 5742        10:15:00                    0
# 5747        19:00:00                    0
#
# [985 rows x 9 columns]

# %%
#Filtro cidades com inicio letra C

filtro_c = df3.ocorrencia_cidade.str[0] == 'C'
df3.loc[filtro_c]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 5661              79649               79649                INCIDENTE
# 5663              79652               79652                INCIDENTE
# 5680              79683               79683                INCIDENTE
# 5696              79692               79692                 ACIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                COARI            AM                 SBUY     2010-01-07
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 20     CRUZEIRO DO SUL            AC                 SBCZ     2010-01-18
# ...                ...           ...                  ...            ...
# 5661          CAMPINAS            SP                 SBKP     2020-11-04
# 5663           CONFINS            MG                 SBCF     2020-11-06
# 5680   CRUZEIRO DO SUL            AC                 SBCZ     2020-11-16
# 5696         CATANDUVA            SP                 SDCD     2020-11-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:40:00                    0
# 7           12:30:00                    3
# 8           23:15:00                    2
# 15          21:22:00                    0
# 20          19:32:00                    0
# ...              ...                  ...
# 5661        22:39:00                    0
# 5663        14:20:00                    0
# 5680        22:00:00                    0
# 5696        12:50:00                    0
# 5747        19:00:00                    0
#
# [825 rows x 9 columns]

# %%
#Filtro cidades com fim letra a

filtro_a = df3.ocorrencia_cidade.str[-1] == 'A'
df3.loc[filtro_a]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 25          UBERLÂNDIA            MG                  NaN     2010-01-20
# 26            SOROCABA            SP                  NaN     2010-01-20
# ...                ...           ...                  ...            ...
# 5738         FORTALEZA            CE                 SBFZ     2020-12-23
# 5739          MARITUBA            PA                  NaN     2020-12-26
# 5743     RIO PARANAÍBA            MG                 SNRP     2020-12-28
# 5744          GOIATUBA            GO                  NaN     2020-12-29
# 5750         VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 12          03:00:00                    0
# 15          21:22:00                    0
# 25          18:58:00                    0
# 26          13:10:00                    0
# ...              ...                  ...
# 5738        18:30:00                    0
# 5739        12:05:00                    0
# 5743        17:00:00                    0
# 5744        12:00:00                    0
# 5750        09:00:00                    0
#
# [1556 rows x 9 columns]

# %%
#Filtro cidades com fim letras ma

filtro_ma = df3.ocorrencia_cidade.str[-2:] == 'MA'
df3.loc[filtro_ma]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2655              51347               51347                INCIDENTE
# 2855              52340               52340                 ACIDENTE
# 2966              52832               52832                 ACIDENTE
# 2997              52979               52979                 ACIDENTE
# 3040              52984               52984                 ACIDENTE
# 3092              53596               53596                INCIDENTE
# 3157              53223               53223                 ACIDENTE
# 3171              53265               53265                 ACIDENTE
# 3189              53271               53271          INCIDENTE GRAVE
# 3682              65414               65414          INCIDENTE GRAVE
# 3725              65633               65633          INCIDENTE GRAVE
# 3881              66265               66265                 ACIDENTE
# 4229              77371               77371                 ACIDENTE
# 4311              77612               77612                 ACIDENTE
# 4574              78080               78080                 ACIDENTE
# 4986              78867               78867                INCIDENTE
# 5070              78923               78923          INCIDENTE GRAVE
# 5080              78782               78782                 ACIDENTE
# 5405              79282               79282                 ACIDENTE
# 5440              79338               79338                INCIDENTE
# 5474              79400               79400                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 408          NOVO GAMA            GO                  NaN     2010-09-25
# 688           BURITAMA            SP                  NaN     2011-03-19
# 1035          BURITAMA            SP                 SIBX     2011-10-25
# 1377          UMUARAMA            PR                  NaN     2012-05-30
# 1401         AURIFLAMA            SP                  NaN     2012-06-16
# 2099         NOVA LIMA            MG                  NaN     2013-06-15
# 2102          CANUTAMA            AM                  NaN     2013-06-18
# 2655           DIADEMA            SP                  NaN     2014-05-04
# 2855              FAMA            MG                  NaN     2014-09-20
# 2966          BURITAMA            SP                  NaN     2014-12-14
# 2997          IVINHEMA            MS                  NaN     2015-01-02
# 3040         NOVA LIMA            MG                 SJLY     2015-02-01
# 3092           ITAPEMA            SC                  NaN     2015-03-10
# 3157         PINDORAMA            SP                  NaN     2015-04-22
# 3171         PACARAIMA            RR                 SDMM     2015-05-05
# 3189          UMUARAMA            PR                  NaN     2015-05-17
# 3682         NOVA LIMA            MG                 SJLY     2016-07-08
# 3725         NOVA LIMA            MG                  NaN     2016-08-31
# 3881          BURITAMA            SP                  NaN     2017-01-13
# 4229          CANUTAMA            AM                 SDKH     2017-11-02
# 4311           ITAPEMA            SC                  NaN     2018-01-06
# 4574           ITAPEMA            SC                  NaN     2018-07-28
# 4986           IRACEMA            RR                  NaN     2019-07-06
# 5070          CANUTAMA            AM                  NaN     2019-09-03
# 5080          IVINHEMA            MS                  NaN     2019-09-08
# 5405           ITURAMA            MG                  NaN     2020-04-11
# 5440          IVINHEMA            MS                  NaN     2020-05-15
# 5474           IBIRAMA            SC                  NaN     2020-06-09
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 15          21:22:00                    0
# 408         16:30:00                    1
# 688         11:18:00                    0
# 1035        19:15:00                    0
# 1377        19:00:00                    0
# 1401        19:30:00                    0
# 2099        12:00:00                    4
# 2102        21:30:00                    0
# 2655        16:00:00                    0
# 2855        15:00:00                    1
# 2966        23:40:00                    0
# 2997        14:50:00                    0
# 3040        15:10:00                    0
# 3092        21:35:00                    0
# 3157        12:45:00                    0
# 3171        16:05:00                    2
# 3189        17:00:00                    0
# 3682        19:50:00                    1
# 3725        17:40:00                    0
# 3881        16:00:00                    0
# 4229        19:30:00                    1
# 4311        10:30:00                    0
# 4574        14:20:00                    0
# 4986        00:00:00                    0
# 5070        14:00:00                    0
# 5080        17:45:00                    0
# 5405        12:20:00                    0
# 5440        09:40:00                    0
# 5474        14:00:00                    0

# %%
#Filtro cidades q contém  letras ma

filtro_ma = df3.ocorrencia_cidade.str.contains('MA')
df3.loc[filtro_ma]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5732              79745               79745                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 13    PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 15              CANUTAMA            AM                  NaN     2010-01-15
# 35                PALMAS            TO                 SBPJ     2010-01-26
# 78                MANAUS            AM                 SBEG     2010-03-07
# ...                  ...           ...                  ...            ...
# 5732              MARABÁ            PA                 SBMA     2020-12-21
# 5739            MARITUBA            PA                  NaN     2020-12-26
# 5741        NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5745           MATO RICO            PR                  NaN     2020-12-29
# 5746       MANOEL URBANO            AC                 SIMB     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 13          17:00:00                    2
# 15          21:22:00                    0
# 35          16:50:00                    0
# 78          19:35:00                    2
# ...              ...                  ...
# 5732        08:47:00                    0
# 5739        12:05:00                    0
# 5741        13:00:00                    0
# 5745        10:30:00                    0
# 5746        18:30:00                    0
#
# [488 rows x 9 columns]

# %%
#Filtro cidades q contém  letras ma ou al

filtro_maal = df3.ocorrencia_cidade.str.contains('MA | AL')
df3.loc[filtro_maal]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 110               40089               40089                 ACIDENTE
# 130               40258               40258                INCIDENTE
# 131               40327               40327                INCIDENTE
# 133               40248               40248                INCIDENTE
# 156               40572               40572                 ACIDENTE
# ...                 ...                 ...                      ...
# 5652              79645               79645                 ACIDENTE
# 5659              79647               79647                INCIDENTE
# 5679              79678               79678                 ACIDENTE
# 5682              79684               79684                INCIDENTE
# 5733              79759               79759                INCIDENTE
#
#                      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 110   VILA BELA DA SANTÍSSIMA TRINDADE            MT                  NaN
# 130                       MONTE ALEGRE            PA                  NaN
# 131                       PORTO ALEGRE            RS                  NaN
# 133                       PORTO ALEGRE            RS                 SBPA
# 156                       PORTO ALEGRE            RS                 SBPA
# ...                                ...           ...                  ...
# 5652                       ALTO ALEGRE            RR                  NaN
# 5659                      PORTO ALEGRE            RS                 SBPA
# 5679  VILA BELA DA SANTÍSSIMA TRINDADE            MT                  NaN
# 5682                      PORTO ALEGRE            RS                 SBPA
# 5733                      PORTO ALEGRE            RS                 SBPA
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 110      2010-03-28        15:10:00                    0
# 130      2010-04-12        18:10:00                    0
# 131      2010-04-12        13:13:00                    0
# 133      2010-04-13        18:47:00                    0
# 156      2010-04-28        14:10:00                    0
# ...             ...             ...                  ...
# 5652     2020-10-28        12:25:00                    0
# 5659     2020-11-01        18:20:00                    0
# 5679     2020-11-16        14:15:00                    0
# 5682     2020-11-17        20:18:00                    0
# 5733     2020-12-21        23:14:00                    0
#
# [136 rows x 9 columns]

# %%
#Filtros em Datas - ano 2015

filtro_data = df3.ocorrencia_dia.dt.year == 2015
df3.loc[filtro_data]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2996              52992               52992          INCIDENTE GRAVE
# 2997              52979               52979                 ACIDENTE
# 2998              53073               53073                INCIDENTE
# 2999              53074               53074                INCIDENTE
# 3000              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2996              SALVADOR            BA                 SBSV     2015-01-01
# 2997              IVINHEMA            MS                  NaN     2015-01-02
# 2998                  TEFÉ            AM                 SBTF     2015-01-02
# 2999        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 3000                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 3462               ITABERÁ            SP                  NaN     2015-12-24
# 3463             GUARULHOS            SP                 SBGR     2015-12-25
# 3464  SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 3465             MAÇAMBARÁ            RS                  NaN     2015-12-28
# 3466            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 2996        11:40:00                    3
# 2997        14:50:00                    0
# 2998        16:28:00                    0
# 2999        20:34:00                    0
# 3000        22:04:00                    6
# ...              ...                  ...
# 3462        14:00:00                    0
# 3463        19:00:00                    0
# 3464        16:00:00                    0
# 3465        19:00:00                    2
# 3466        14:00:00                    0
#
# [471 rows x 9 columns]

# %%
#Filtros em Datas - ano 2016 mês 12

filtro_data = df3.ocorrencia_dia.dt.year == 2016
filtro_mes = df3.ocorrencia_dia.dt.month == 12
df3.loc[filtro_data & filtro_mes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3832              66081               66081                INCIDENTE
# 3833              66073               66073                INCIDENTE
# 3834              66083               66083          INCIDENTE GRAVE
# 3835              66076               66076          INCIDENTE GRAVE
# 3836              66066               66066                 ACIDENTE
# 3837              66075               66075                INCIDENTE
# 3838              66078               66078                 ACIDENTE
# 3839              66430               66430                INCIDENTE
# 3840              66084               66084                 ACIDENTE
# 3841              66086               66086                 ACIDENTE
# 3842              66088               66088                INCIDENTE
# 3843              66089               66089                INCIDENTE
# 3844              66090               66090          INCIDENTE GRAVE
# 3845              66121               66121                INCIDENTE
# 3846              66127               66127          INCIDENTE GRAVE
# 3847              66210               66210          INCIDENTE GRAVE
# 3848              66093               66093                 ACIDENTE
# 3849              66094               66094          INCIDENTE GRAVE
# 3850              66100               66100                 ACIDENTE
# 3851              66109               66109                INCIDENTE
# 3852              66128               66128                 ACIDENTE
# 3853              66145               66145                INCIDENTE
# 3854              66129               66129                INCIDENTE
# 3855              66131               66131                 ACIDENTE
# 3856              66140               66140                INCIDENTE
# 3857              66160               66160                 ACIDENTE
# 3858              66273               66273                INCIDENTE
# 3859              66155               66155                INCIDENTE
# 3860              66156               66156                 ACIDENTE
# 3861              66158               66158                INCIDENTE
# 3862              66159               66159                 ACIDENTE
# 3863              66197               66197                INCIDENTE
# 3864              66192               66192                 ACIDENTE
# 3865              66221               66221                 ACIDENTE
# 3866              66695               66695                INCIDENTE
# 3867              66759               66759                INCIDENTE
# 3868              66198               66198                 ACIDENTE
# 3869              66204               66204                 ACIDENTE
#
#             ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 3832                SÃO PAULO            SP                 SBMT
# 3833                FORTALEZA            CE                 SBFZ
# 3834        BRAGANÇA PAULISTA            SP                 SBBP
# 3835                  CARUARU            PE                  NaN
# 3836  SANTA VITÓRIA DO PALMAR            RS                  NaN
# 3837              PATO BRANCO            PR                 SSPB
# 3838    SÃO LOURENÇO DA SERRA            SP                  NaN
# 3839                SÃO PAULO            SP                 SBSP
# 3840             CRUZ MACHADO            PR                  NaN
# 3841                   MANAUS            AM                  NaN
# 3842                 SOROCABA            SP                 SDCO
# 3843                GUARULHOS            SP                 SBGR
# 3844        BRAGANÇA PAULISTA            SP                 SBBP
# 3845                  GOIÂNIA            GO                 SWNV
# 3846                  GOIÂNIA            GO                 SWNV
# 3847                    TAPES            RS                  NaN
# 3848                 ITAITUBA            PA                 SNYR
# 3849                  ERECHIM            RS                  NaN
# 3850           NOVO HORIZONTE            SP                 SDNH
# 3851             PORTO ALEGRE            RS                 SBPA
# 3852       PRIMAVERA DO LESTE            MT                  NaN
# 3853    CAMPOS DOS GOYTACAZES            RJ                 SBCP
# 3854      SÃO JOSÉ DOS CAMPOS            SP                 SBSJ
# 3855  SANTA VITÓRIA DO PALMAR            RS                  NaN
# 3856                 LONDRINA            PR                 SBLO
# 3857    SANTA HELENA DE GOIÁS            GO                  NaN
# 3858                  JUNDIAÍ            SP                 SBJD
# 3859                SÃO PAULO            SP                 SBMT
# 3860                TABATINGA            AM                  NaN
# 3861                SÃO PAULO            SP                 SBMT
# 3862           NOVO HORIZONTE            SP                  NaN
# 3863                PETROLINA            PE                 SBPL
# 3864                    MARAÚ            BA                 SIRI
# 3865                GUARAPARI            ES                 SNGA
# 3866                 LUZIÂNIA            GO                 SWUZ
# 3867               BARRO ALTO            GO                  NaN
# 3868                  CORINTO            MG                  NaN
# 3869               URUGUAIANA            RS                  NaN
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 3832     2016-12-01        14:45:00                    0
# 3833     2016-12-02        19:30:00                    0
# 3834     2016-12-02        20:46:00                    0
# 3835     2016-12-03        10:25:00                    1
# 3836     2016-12-04        12:00:00                    0
# 3837     2016-12-04        18:23:00                    0
# 3838     2016-12-04        18:30:00                    2
# 3839     2016-12-04        11:54:00                    0
# 3840     2016-12-05        14:15:00                    0
# 3841     2016-12-07        11:50:00                    2
# 3842     2016-12-07        15:43:00                    0
# 3843     2016-12-07        20:45:00                    0
# 3844     2016-12-07        19:10:00                    1
# 3845     2016-12-07        10:30:00                    0
# 3846     2016-12-08        12:30:00                    0
# 3847     2016-12-08        10:30:00                    0
# 3848     2016-12-09        18:30:00                    1
# 3849     2016-12-10        14:30:00                    1
# 3850     2016-12-10        22:20:00                    0
# 3851     2016-12-12        09:34:00                    0
# 3852     2016-12-13        19:30:00                    0
# 3853     2016-12-14        16:05:00                    0
# 3854     2016-12-15        13:30:00                    0
# 3855     2016-12-15        18:40:00                    3
# 3856     2016-12-15        13:05:00                    0
# 3857     2016-12-15        13:00:00                    0
# 3858     2016-12-15        14:20:00                    0
# 3859     2016-12-19        09:48:00                    0
# 3860     2016-12-23        17:30:00                    2
# 3861     2016-12-23        14:57:00                    0
# 3862     2016-12-23        10:00:00                    0
# 3863     2016-12-26        09:15:00                    0
# 3864     2016-12-27        19:00:00                    1
# 3865     2016-12-28        19:00:00                    1
# 3866     2016-12-28        17:00:00                    0
# 3867     2016-12-30        20:30:00                    0
# 3868     2016-12-31        17:00:00                    0
# 3869     2016-12-31        20:00:00                    1

# %%
#Filtros em Datas - ano 2020 mês 5 dia 10

filtro_data = df3.ocorrencia_dia.dt.year == 2015
filtro_mes = df3.ocorrencia_dia.dt.month == 12
filtro_dia = df3.ocorrencia_dia.dt.day == 8
df3.loc[filtro_data & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3436             AGUAÍ            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# 3438          CAMPINAS            SP                 SBKP     2015-12-08
# 3439     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
#Filtros em Datas - ano 2020 mês 5 dia 3 ao dia 10

filtro_data = df3.ocorrencia_dia.dt.year == 2015
filtro_mes = df3.ocorrencia_dia.dt.month == 12
filtro_dia = (df3.ocorrencia_dia.dt.day >= 3) & (df3.ocorrencia_dia.dt.day <= 10)
df3.loc[filtro_data & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# 3435              AMERICANA            SP                 SDAI     2015-12-06
# 3436                  AGUAÍ            SP                  NaN     2015-12-08
# 3437                  JALES            SP                 SDJL     2015-12-08
# 3438               CAMPINAS            SP                 SBKP     2015-12-08
# 3439          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3432        10:50:00                    0
# 3433        16:47:00                    0
# 3434        13:10:00                    3
# 3435        15:00:00                    1
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
#Transformando duas colunas em uma data e hora

df3 = ['ocorrencia_dia_hora'] = df3.ocorrencia_dia + ' ' + df3.ocorrencia_hora
# Out:
#   File "<ipython-input-174-95935eb6fc03>", line 3
#     df3 = ['ocorrencia_dia_hora'] = df3.ocorrencia_dia + ' ' + df3.ocorrencia_hora
#           ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# O erro acima acontece pq não é possível unir algo do tipo data (dia) com algo do tipo strink (hora).
#
# Precisamos transformar o tipo data em string:

# %%
df3.ocorrencia_dia.astype(str) + ' ' + df3.ocorrencia_hora
# Out:
# 0       2010-01-03 12:00:00
# 1       2010-01-03 11:05:00
# 2       2010-01-03 03:00:00
# 3       2010-01-04 17:30:00
# 4       2010-01-05 19:25:00
#                ...
# 5748    2020-12-30 18:30:00
# 5749    2020-12-30 00:54:00
# 5750    2020-12-31 09:00:00
# 5751    2020-12-31 13:24:00
# 5752    2021-01-01 13:24:00
# Length: 5753, dtype: object

# %% [markdown]
# ### Agrupamento de valores

# %%
filtro1 = df3.ocorrencia_dia.dt.year == 2015
filtro2 = df3.ocorrencia_dia.dt.month == 12

df201503 = df3.loc[filtro1 & filtro2]

df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3428              53573               53573                INCIDENTE
# 3429              60601               60601                INCIDENTE
# 3430              53634               53634                INCIDENTE
# 3431              53636               53636                INCIDENTE
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
# 3440              53627               53627                INCIDENTE
# 3441              60604               60604                INCIDENTE
# 3442              60611               60611                INCIDENTE
# 3443              60613               60613                 ACIDENTE
# 3444              60629               60629                 ACIDENTE
# 3445              53630               53630                INCIDENTE
# 3446              60603               60603                INCIDENTE
# 3447              60612               60612                 ACIDENTE
# 3448              60783               60783                 ACIDENTE
# 3449              53639               53639                INCIDENTE
# 3450              60609               60609          INCIDENTE GRAVE
# 3451              60616               60616                 ACIDENTE
# 3452              60620               60620                 ACIDENTE
# 3453              60645               60645                 ACIDENTE
# 3454              60608               60608                INCIDENTE
# 3455              60625               60625                 ACIDENTE
# 3456              60605               60605                INCIDENTE
# 3457              60610               60610                INCIDENTE
# 3458              60602               60602                INCIDENTE
# 3459              60615               60615                INCIDENTE
# 3460              60640               60640                INCIDENTE
# 3461              60641               60641                INCIDENTE
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3428              GUARULHOS            SP                 SBGR     2015-12-01
# 3429                 PALMAS            TO                 SBPJ     2015-12-01
# 3430                 PALMAS            TO                 SBPJ     2015-12-02
# 3431                JUNDIAÍ            SP                 SBJD     2015-12-02
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# 3435              AMERICANA            SP                 SDAI     2015-12-06
# 3436                  AGUAÍ            SP                  NaN     2015-12-08
# 3437                  JALES            SP                 SDJL     2015-12-08
# 3438               CAMPINAS            SP                 SBKP     2015-12-08
# 3439          CAXIAS DO SUL            RS                 SBCX     2015-12-08
# 3440               TERESINA            PI                 SBTE     2015-12-12
# 3441                GOIÂNIA            GO                 SBGO     2015-12-12
# 3442              SÃO PAULO            SP                 SBSP     2015-12-12
# 3443             JUSCIMEIRA            MT                 SWMO     2015-12-12
# 3444             RIO GRANDE            RS                  NaN     2015-12-12
# 3445                MARÍLIA            SP                 SBML     2015-12-13
# 3446               LONDRINA            PR                 SBLO     2015-12-13
# 3447        BENTO GONÇALVES            RS                 SSBG     2015-12-13
# 3448                  LAGES            SC                  NaN     2015-12-13
# 3449               LOUVEIRA            SP                 SDAM     2015-12-15
# 3450              ARAGUAÍNA            TO                 SWGN     2015-12-15
# 3451               PALOTINA            PR                  NaN     2015-12-15
# 3452         RIO DE JANEIRO            RJ                 SBJR     2015-12-15
# 3453            SERTÃOZINHO            SP                  NaN     2015-12-15
# 3454         BELO HORIZONTE            MG                 SBPR     2015-12-16
# 3455               ITÁPOLIS            SP                 SDIO     2015-12-17
# 3456             UBERLÂNDIA            MG                 SBUL     2015-12-18
# 3457                JUNDIAÍ            SP                 SBJD     2015-12-18
# 3458         RIBEIRÃO PRETO            SP                 SBRP     2015-12-22
# 3459              SÃO PAULO            SP                 SBMT     2015-12-22
# 3460               CASCAVEL            PR                 SBCA     2015-12-23
# 3461         BELO HORIZONTE            MG                 SBBH     2015-12-23
# 3462                ITABERÁ            SP                  NaN     2015-12-24
# 3463              GUARULHOS            SP                 SBGR     2015-12-25
# 3464   SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 3465              MAÇAMBARÁ            RS                  NaN     2015-12-28
# 3466             PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 3428        02:48:00                    0
# 3429        16:05:00                    0
# 3430        17:45:00                    0
# 3431        17:42:00                    0
# 3432        10:50:00                    0
# 3433        16:47:00                    0
# 3434        13:10:00                    3
# 3435        15:00:00                    1
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0
# 3440        19:05:00                    0
# 3441        14:34:00                    0
# 3442        15:30:00                    0
# 3443        08:31:00                    0
# 3444        10:40:00                    0
# 3445        13:50:00                    0
# 3446        17:46:00                    0
# 3447        20:30:00                    0
# 3448        14:00:00                    3
# 3449        14:20:00                    0
# 3450        13:00:00                    0
# 3451        20:30:00                    0
# 3452        16:50:00                    4
# 3453        13:00:00                    0
# 3454        10:38:00                    0
# 3455        21:30:00                    1
# 3456        10:25:00                    0
# 3457        18:45:00                    0
# 3458        06:27:00                    0
# 3459        13:07:00                    0
# 3460        13:20:00                    0
# 3461        15:53:00                    0
# 3462        14:00:00                    0
# 3463        19:00:00                    0
# 3464        16:00:00                    0
# 3465        19:00:00                    2
# 3466        14:00:00                    0

# %%
df201503.count()
# Out:
# codigo_ocorrencia           39
# codigo_ocorrencia2          39
# ocorrencia_classificacao    39
# ocorrencia_cidade           39
# ocorrencia_uf               39
# ocorrencia_aerodromo        31
# ocorrencia_dia              39
# ocorrencia_hora             39
# total_recomendacoes         39
# dtype: int64

# %%
#Agrupando codigo de ococrrencia

df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           14
# INCIDENTE          23
# INCIDENTE GRAVE     2
# Name: codigo_ocorrencia, dtype: int64

# %%
#ou

df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           14
# INCIDENTE          23
# INCIDENTE GRAVE     2
# dtype: int64

# %%
#ordenando valores ordem crescente

df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     2
# ACIDENTE           14
# INCIDENTE          23
# dtype: int64

# %%
#ordenando valores ordem decrescente

df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          23
# ACIDENTE           14
# INCIDENTE GRAVE     2
# dtype: int64

# %%
#Agrupando dados da região sudeste ano 2010

filtro_ano = df3.ocorrencia_dia.dt.year == 2010
filtro_regiao = df3.ocorrencia_uf.isin(['SP','MG','ES','RJ'])
dfsudeste2010 = df3.loc[filtro_ano & filtro_regiao]

dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 9       PARÁ DE MINAS            MG                  NaN     2010-01-10
# 11          SÃO PAULO            SP                 SBMT     2010-01-10
# 16          SÃO PAULO            SP                  NaN     2010-01-15
# ..                ...           ...                  ...            ...
# 541            CAJOBI            SP                  NaN     2010-12-23
# 544         SÃO PAULO            SP                 SBSP     2010-12-26
# 548        COSMÓPOLIS            SP                  NaN     2010-12-29
# 550           VITÓRIA            ES                  NaN     2010-12-30
# 551   ARRAIAL DO CABO            RJ                  NaN     2010-12-30
#
#     ocorrencia_hora  total_recomendacoes
# 0          12:00:00                    0
# 2          03:00:00                    0
# 9          20:00:00                    0
# 11         14:50:00                    8
# 16         15:00:00                    0
# ..              ...                  ...
# 541        11:00:00                    0
# 544        22:10:00                    0
# 548        12:00:00                    0
# 550        18:10:00                    0
# 551        14:28:00                    0
#
# [228 rows x 9 columns]

# %%
#contando

dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
#contando classificação por estado

dfsudeste2010.groupby(['ocorrencia_classificacao', 'ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
#contando classificação por cidade


dfsudeste2010.groupby(['ocorrencia_cidade']).size()
# Out:
# ocorrencia_cidade
# AMERICANA                 1
# ARARAQUARA                2
# ARAÇATUBA                 1
# AREALVA                   2
# ARRAIAL DO CABO           1
# BAURU                     2
# BEBEDOURO                 1
# BELO HORIZONTE           17
# BOCAINA                   1
# BOITUVA                   1
# BOM JESUS DO AMPARO       1
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         1
# BROTAS                    1
# CAJOBI                    1
# CAMANDUCAIA               1
# CAMPINAS                 13
# CAMPOS DOS GOYTACAZES     2
# CASIMIRO DE ABREU         1
# CONFINS                   7
# COROMANDEL                1
# COSMÓPOLIS                1
# DIAMANTINA                1
# DIVINÓPOLIS               2
# GUARULHOS                18
# IPATINGA                  2
# IPERÓ                     1
# ITANHAÉM                  2
# ITÁPOLIS                  1
# JUIZ DE FORA              4
# JUNDIAÍ                   2
# LINHARES                  1
# MACAÉ                    12
# MANGARATIBA               1
# MARÍLIA                   3
# MONTES CLAROS             2
# NOVO HORIZONTE            1
# OLÍMPIA                   1
# PARÁ DE MINAS             1
# PENÁPOLIS                 1
# PIACATU                   1
# PIRACICABA                1
# PIRASSUNUNGA              1
# POUSO ALEGRE              1
# POÇOS DE CALDAS           2
# RESENDE                   1
# RIBEIRÃO PRETO            2
# RIO DE JANEIRO           47
# SANTOS                    1
# SERRA NEGRA               1
# SOROCABA                  2
# SÃO BERNARDO DO CAMPO     1
# SÃO JOSÉ DO RIO PRETO     3
# SÃO JOSÉ DOS CAMPOS       3
# SÃO PAULO                33
# TIMÓTEO                   1
# UBERABA                   2
# UBERLÂNDIA                5
# VITÓRIA                   4
# dtype: int64

# %%
#Classificando ordem decrescente

dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# JUIZ DE FORA              4
# VITÓRIA                   4
# MARÍLIA                   3
# SÃO JOSÉ DOS CAMPOS       3
# SÃO JOSÉ DO RIO PRETO     3
# SOROCABA                  2
# ITANHAÉM                  2
# RIBEIRÃO PRETO            2
# IPATINGA                  2
# POÇOS DE CALDAS           2
# DIVINÓPOLIS               2
# BAURU                     2
# JUNDIAÍ                   2
# ARARAQUARA                2
# CAMPOS DOS GOYTACAZES     2
# AREALVA                   2
# MONTES CLAROS             2
# UBERABA                   2
# POUSO ALEGRE              1
# PIRACICABA                1
# PIRASSUNUNGA              1
# ARRAIAL DO CABO           1
# RESENDE                   1
# PENÁPOLIS                 1
# SANTOS                    1
# SERRA NEGRA               1
# SÃO BERNARDO DO CAMPO     1
# TIMÓTEO                   1
# ARAÇATUBA                 1
# PIACATU                   1
# BOM JESUS DO AMPARO       1
# PARÁ DE MINAS             1
# OLÍMPIA                   1
# BRAGANÇA PAULISTA         1
# BROTAS                    1
# CAJOBI                    1
# CAMANDUCAIA               1
# BOITUVA                   1
# CASIMIRO DE ABREU         1
# BOCAINA                   1
# COROMANDEL                1
# COSMÓPOLIS                1
# DIAMANTINA                1
# BEBEDOURO                 1
# IPERÓ                     1
# ITÁPOLIS                  1
# LINHARES                  1
# MANGARATIBA               1
# BOM JESUS DO GALHO        1
# NOVO HORIZONTE            1
# AMERICANA                 1
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False).head()
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO    47
# SÃO PAULO         33
# GUARULHOS         18
# BELO HORIZONTE    17
# CAMPINAS          13
# dtype: int64

# %%
#Verificar informações de cidade com maior ocorrencias:

filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 19               44575               44575                INCIDENTE
# 23               40311               40311                INCIDENTE
# 24               41577               41577                INCIDENTE
# 30               39849               39849                INCIDENTE
# 39               40617               40617                INCIDENTE
# 49               39295               39295                 ACIDENTE
# 71               39987               39987                INCIDENTE
# 101              40210               40210                INCIDENTE
# 105              40209               40209                INCIDENTE
# 107              40330               40330                INCIDENTE
# 119              40190               40190                INCIDENTE
# 139              40294               40294                INCIDENTE
# 144              40293               40293                INCIDENTE
# 154              40581               40581                INCIDENTE
# 164              40774               40774                INCIDENTE
# 185              41573               41573                INCIDENTE
# 223              41591               41591                INCIDENTE
# 240              41678               41678                INCIDENTE
# 242              42011               42011                INCIDENTE
# 248              41729               41729                 ACIDENTE
# 274              41750               41750                 ACIDENTE
# 284              42067               42067                INCIDENTE
# 296              42634               42634                INCIDENTE
# 298              42436               42436                INCIDENTE
# 300              42619               42619                INCIDENTE
# 309              42443               42443                INCIDENTE
# 319              42284               42284                INCIDENTE
# 326              42250               42250                 ACIDENTE
# 335              42456               42456                INCIDENTE
# 336              42740               42740                INCIDENTE
# 341              42486               42486                INCIDENTE
# 352              42603               42603                INCIDENTE
# 359              42598               42598                INCIDENTE
# 375              42714               42714          INCIDENTE GRAVE
# 377              42868               42868                INCIDENTE
# 386              43064               43064                INCIDENTE
# 388              42880               42880          INCIDENTE GRAVE
# 389              42882               42882          INCIDENTE GRAVE
# 427              43578               43578                INCIDENTE
# 432              43033               43033                INCIDENTE
# 456              43699               43699                INCIDENTE
# 494              43283               43283                INCIDENTE
# 526              43527               43527                INCIDENTE
# 527              43462               43462          INCIDENTE GRAVE
# 536              43921               43921                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 19     RIO DE JANEIRO            RJ                 SBGL     2010-01-17
# 23     RIO DE JANEIRO            RJ                  NaN     2010-01-19
# 24     RIO DE JANEIRO            RJ                  NaN     2010-01-19
# 30     RIO DE JANEIRO            RJ                 SBGL     2010-01-23
# 39     RIO DE JANEIRO            RJ                 SBGL     2010-01-27
# 49     RIO DE JANEIRO            RJ                  NaN     2010-02-06
# 71     RIO DE JANEIRO            RJ                 SBJR     2010-02-24
# 101    RIO DE JANEIRO            RJ                 SBJR     2010-03-20
# 105    RIO DE JANEIRO            RJ                 SBJR     2010-03-21
# 107    RIO DE JANEIRO            RJ                  NaN     2010-03-24
# 119    RIO DE JANEIRO            RJ                 SBGL     2010-04-06
# 139    RIO DE JANEIRO            RJ                  NaN     2010-04-16
# 144    RIO DE JANEIRO            RJ                 SBJR     2010-04-18
# 154    RIO DE JANEIRO            RJ                 SBJR     2010-04-21
# 164    RIO DE JANEIRO            RJ                 SBGL     2010-05-01
# 185    RIO DE JANEIRO            RJ                 SBJR     2010-05-13
# 223    RIO DE JANEIRO            RJ                 SBGL     2010-06-10
# 240    RIO DE JANEIRO            RJ                 SBRJ     2010-06-19
# 242    RIO DE JANEIRO            RJ                  NaN     2010-06-19
# 248    RIO DE JANEIRO            RJ                  NaN     2010-06-25
# 274    RIO DE JANEIRO            RJ                 SBJR     2010-07-12
# 284    RIO DE JANEIRO            RJ                  NaN     2010-07-20
# 296    RIO DE JANEIRO            RJ                  NaN     2010-07-28
# 298    RIO DE JANEIRO            RJ                 SBJR     2010-07-29
# 300    RIO DE JANEIRO            RJ                 SBRJ     2010-07-30
# 309    RIO DE JANEIRO            RJ                 SBGL     2010-08-04
# 319    RIO DE JANEIRO            RJ                 SBGL     2010-08-10
# 326    RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
# 335    RIO DE JANEIRO            RJ                  NaN     2010-08-21
# 336    RIO DE JANEIRO            RJ                  NaN     2010-08-21
# 341    RIO DE JANEIRO            RJ                 SBRJ     2010-08-23
# 352    RIO DE JANEIRO            RJ                  NaN     2010-08-27
# 359    RIO DE JANEIRO            RJ                  NaN     2010-08-31
# 375    RIO DE JANEIRO            RJ                  NaN     2010-09-11
# 377    RIO DE JANEIRO            RJ                  NaN     2010-09-11
# 386    RIO DE JANEIRO            RJ                 SBRJ     2010-09-15
# 388    RIO DE JANEIRO            RJ                 SBJR     2010-09-17
# 389    RIO DE JANEIRO            RJ                 SBJR     2010-09-17
# 427    RIO DE JANEIRO            RJ                  NaN     2010-10-04
# 432    RIO DE JANEIRO            RJ                  NaN     2010-10-05
# 456    RIO DE JANEIRO            RJ                 SBJR     2010-10-23
# 494    RIO DE JANEIRO            RJ                 SBJR     2010-11-20
# 526    RIO DE JANEIRO            RJ                 SBRJ     2010-12-12
# 527    RIO DE JANEIRO            RJ                 SBGL     2010-12-13
# 536    RIO DE JANEIRO            RJ                  NaN     2010-12-18
#
#     ocorrencia_hora  total_recomendacoes
# 0          12:00:00                    0
# 2          03:00:00                    0
# 19         12:27:00                    0
# 23         13:20:00                    0
# 24         12:16:00                    0
# 30         03:30:00                    0
# 39         20:06:00                    0
# 49         21:09:00                    0
# 71         19:37:00                    0
# 101        20:02:00                    0
# 105        13:46:00                    0
# 107        11:35:00                    0
# 119        02:35:00                    3
# 139        20:00:00                    0
# 144        16:23:00                    0
# 154        13:20:00                    0
# 164        02:10:00                    0
# 185        16:10:00                    0
# 223        17:30:00                    0
# 240        19:05:00                    0
# 242        13:16:00                    0
# 248        13:05:00                    0
# 274        19:53:00                    3
# 284        12:41:00                    0
# 296        10:05:00                    0
# 298        19:12:00                    0
# 300        09:24:00                    0
# 309        13:27:00                    0
# 319        12:30:00                    0
# 326        12:26:00                   19
# 335        16:35:00                    0
# 336        13:25:00                    0
# 341        23:55:00                    0
# 352        13:27:00                    0
# 359        12:35:00                    0
# 375        15:30:00                    0
# 377        20:30:00                    0
# 386        17:54:00                    0
# 388        13:55:00                    0
# 389        18:46:00                    0
# 427        12:30:00                    0
# 432        21:46:00                    0
# 456        17:43:00                    0
# 494        13:02:00                    0
# 526        19:00:00                    0
# 527        11:00:00                    0
# 536        13:15:00                    0

# %%
#Verificando total de recomendações que o RJ teve

filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
#Verificando total de recomendações da Região Sudeste

dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# AMERICANA                 0
# ARARAQUARA                0
# ARAÇATUBA                 0
# AREALVA                   0
# ARRAIAL DO CABO           0
# BAURU                     0
# BEBEDOURO                 0
# BELO HORIZONTE            2
# BOCAINA                   0
# BOITUVA                   1
# BOM JESUS DO AMPARO       0
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# BROTAS                    0
# CAJOBI                    0
# CAMANDUCAIA               9
# CAMPINAS                  0
# CAMPOS DOS GOYTACAZES     0
# CASIMIRO DE ABREU         0
# CONFINS                   0
# COROMANDEL                0
# COSMÓPOLIS                0
# DIAMANTINA                0
# DIVINÓPOLIS               0
# GUARULHOS                 0
# IPATINGA                  0
# IPERÓ                     3
# ITANHAÉM                  1
# ITÁPOLIS                  0
# JUIZ DE FORA              0
# JUNDIAÍ                   7
# LINHARES                  0
# MACAÉ                     0
# MANGARATIBA               0
# MARÍLIA                   0
# MONTES CLAROS             0
# NOVO HORIZONTE            3
# OLÍMPIA                   0
# PARÁ DE MINAS             0
# PENÁPOLIS                 0
# PIACATU                   0
# PIRACICABA                0
# PIRASSUNUNGA              0
# POUSO ALEGRE              0
# POÇOS DE CALDAS           0
# RESENDE                   8
# RIBEIRÃO PRETO            0
# RIO DE JANEIRO           25
# SANTOS                    0
# SERRA NEGRA               0
# SOROCABA                  0
# SÃO BERNARDO DO CAMPO     2
# SÃO JOSÉ DO RIO PRETO     0
# SÃO JOSÉ DOS CAMPOS       0
# SÃO PAULO                41
# TIMÓTEO                   3
# UBERABA                   0
# UBERLÂNDIA                0
# VITÓRIA                   0
# Name: total_recomendacoes, dtype: int64

# %%
#Verificando total da Região Sudeste q tiveram de recomendações

filtro_a = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro_a].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_aerodromo']).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# Name: total_recomendacoes, dtype: int64

# %%
#importante lembrar de conferir os valores nulos, nesse caso tempo 45 aerodromos que não foram classificados e eles tiveram 45 recomendações

dfsudeste2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# NaN     45
# Name: total_recomendacoes, dtype: int64

# %% [markdown]
# # Carregamento de Dados
#
# Não Trataremos essa questão pelo fato de exister varias formas e ferramentas diferentes nesse contexto, onde cada uma requer um método e um código a ser seguido.

# %%
dfsudeste2010.tail()
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 541            CAJOBI            SP                  NaN     2010-12-23
# 544         SÃO PAULO            SP                 SBSP     2010-12-26
# 548        COSMÓPOLIS            SP                  NaN     2010-12-29
# 550           VITÓRIA            ES                  NaN     2010-12-30
# 551   ARRAIAL DO CABO            RJ                  NaN     2010-12-30
#
#     ocorrencia_hora  total_recomendacoes
# 541        11:00:00                    0
# 544        22:10:00                    0
# 548        12:00:00                    0
# 550        18:10:00                    0
# 551        14:28:00                    0
